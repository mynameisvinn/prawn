# %%
from scholarly import scholarly

# %%
curr = "Liang Liang Cao"

# %%
search_query = scholarly.search_author(curr)
author = next(search_query).fill(sections=['publications'])

# %%
author
# Out:
# {'affiliation': 'National Cancer Institute',
#  'citedby': 6419,
#  'email': '@mail.nih.gov',
#  'filled': False,
#  'id': 'tN2iKyEAAAAJ',
#  'interests': ['Cancer', 'drug development', 'biomarker'],
#  'name': 'Liang Cao',
#  'publications': [{'bib': {'cites': '987',
#          'title': 'A method for gene disruption that allows repeated use of '
#                   'URA3 selection in the construction of multiply disrupted '
#                   'yeast strains',
#          'year': '1987'},
#  'filled': False,
#  'id_citations': 'tN2iKyEAAAAJ:MXK_kJrjxJIC',
#  'source': 'citations'},
#                   {'bib': {'cites': '717',
#          'title': 'A pathway for generation and processing of double-strand '
#                   'breaks during meiotic recombination in S. cerevisiae',
#          'year': '1990'},
#  'filled': False,
#  'id_citations': 'tN2iKyEAAAAJ:3fE2CSJIrl8C',
#  'source': 'citations'},
#                   {'bib': {'cites': '463',
# ...
